# %% [markdown]
# ## Урок 4. Визуальный анализ данных

# %% [markdown]
# ### Условие 1: Задача 1
# * Постройте график
# * Назовите график
# * Сделайте именование оси x и оси y
# * Сделайте выводы

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
plt.plot([0, 1, 2, 3], [10, 9, 6, 1])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Example')
plt.grid();

# %% [markdown]
# 1.1. Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices

# %%
df = pd.read_csv('kc_house_data3.csv')
df.sample(n=10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3638   7877400266  20150407T000000   206000.0         3       1.00
# 18598   726049131  20150320T000000   325000.0         3       2.00
# 15761  8638500020  20140911T000000   315000.0         3       1.00
# 7562   4077800412  20150316T000000   563000.0         3       1.50
# 1751   3856904740  20141021T000000   490000.0         2       1.00
# 15417  2929600020  20140805T000000   375000.0         3       1.50
# 7273   1245500250  20150507T000000   555500.0         2       1.00
# 2605   9476700135  20150319T000000   300000.0         3       1.75
# 11616  7932600140  20140703T000000   395000.0         4       2.75
# 16825  3025300095  20141009T000000  2500000.0         4       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3638           970      9360     1.0           0     0  ...      5
# 18598         1750      9000     1.5           0     0  ...      5
# 15761         1210      8505     1.5           0     0  ...      7
# 7562          1730      9509     2.0           0     0  ...      8
# 1751           950      3060     1.0           0     0  ...      6
# 15417         1190     20672     1.5           0     3  ...      7
# 7273           920     10000     1.0           0     0  ...      7
# 2605          1500      8352     1.0           0     2  ...      6
# 11616         2640     35070     1.5           0     0  ...      8
# 16825         4300     19844     2.0           0     0  ...     11
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3638          970              0      1942             0    98002  47.2808
# 18598        1750              0      1936             0    98133  47.7489
# 15761        1210              0      1958             0    98106  47.5389
# 7562         1270            460      1955             0    98125  47.7067
# 1751          810            140      1925             0    98105  47.6698
# 15417        1190              0      1948             0    98166  47.4459
# 7273          920              0      1981             0    98033  47.6938
# 2605          750            750      1943             0    98056  47.4883
# 11616        2640              0      1963             0    98058  47.4242
# 16825        4300              0      1985          1999    98039  47.6218
#
#           long  sqft_living15  sqft_lot15
# 3638  -122.225           1050       11348
# 18598 -122.350           1830        8100
# 15761 -122.353           1430        8505
# 7562  -122.282           1810        8795
# 1751  -122.323           1510        3780
# 15417 -122.359           2150       16239
# 7273  -122.210           1340       10000
# 2605  -122.191           1500        8447
# 11616 -122.181           2520       34986
# 16825 -122.237           3070       19845
#
# [10 rows x 21 columns]

# %% [markdown]
# 1.2 Изучите стоимости недвижимости

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['price'], bins=100)

plt.title('Стоимость недвижимости')
plt.xlabel('Цена')
plt.ylabel('Количиство')
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# 1.3 Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df['sqft_living'], bins=100)

plt.title('Распределение жилой прощади')
plt.xlabel('Жилая площадь')
df['sqft_living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %% [markdown]
# 1.4 Изучите распределение года постройки

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df['yr_built'], bins=100)

plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
df['yr_built'].describe()
# Out:
# count    21613.000000
# mean      1971.005136
# std         29.373411
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %% [markdown]
# ### Условие 2: 2 задача

# %% [markdown]
# 2.1 Изучите распределение домов от наличия вида на набережную
# * Постройте график
# * Сделайте выводы

# %%
data = df['waterfront'].value_counts()
data.index = ['no', 'yes']
data.head()
# Out:
# no     21450
# yes      163
# Name: waterfront, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.pie(data, autopct='%1.1f%%')

plt.title('Доля домов с видом на набережную')
plt.legend(data.index);

# %% [markdown]
# 2.2 Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
data
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['floors'])

plt.title('Распределение домов по количеству этажей')
plt.xlabel('Число этажей')
plt.ylabel('Количиство домов');

# %% [markdown]
# 2.3 Изучите распределение состояния домов

# %%
data = df['grade'].value_counts()
data
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['grade'])

plt.title('Распределение домов по их состоянию')
plt.xlabel('Состояние дома')
plt.ylabel('Количество домов');

# %% [markdown]
# ### Условие 3: 3 задача

# %% [markdown]
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(8, 6))

sns.jointplot(x=df['price'], y=df['sqft_living'], kind='reg')
plt.title('Отношение цены и площади недвижимости');

# %% [markdown]
# На этом графике видно, что площадь недвижимости влияет но стоимость

# %%
plt.figure(figsize=(8, 6))

sns.jointplot(x=df['price'], y=df['bedrooms'], kind='reg')
plt.title('Отношение цены и количества спален');

# %% [markdown]
# Из графика видно, что количество спален не сильно влияет на стоимость недвижимости

# %%
plt.figure(figsize=(8, 6))

sns.jointplot(x=df['price'], y=df['bathrooms'], kind='reg')
plt.title('Отношение цены и ванных комнат');

# %% [markdown]
# Из графика видно, что ванные комноты не влияют на стоимость недвижимости

# %%
plt.figure(figsize=(8, 6))

sns.jointplot(x=df['price'], y=df['floors'], kind='reg')
plt.title('Отношение цены и количества этажей');

# %% [markdown]
# Из графика видно, что наиболее ценятся дома не выше 2.5 этажей. Выше дома теряют в цене

# %%
plt.figure(figsize=(8, 6))

sns.jointplot(x=df['price'], y=df['grade'], kind='reg')
plt.title('Отношение цены и класса недвижимости');

# %% [markdown]
# Из графика видно, что класс жилья существенно влияет на его стоимость

# %% [markdown]
# Вывод.
# Из графиков выше видно, что из 5 характеристик недвижимости не влияют на её стоимость
# количество спален и ванные комнаты, имеют значение площадь недвижимости и количество этажей,
# но не выше 2.5 и особое влияние на стоимость оказывает класс недвижимости.
