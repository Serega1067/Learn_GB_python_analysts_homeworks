# %% [markdown]
# ## Урок 3. Изменение таблиц в Pandas

# %% [markdown]
# ### Условие 1: Задача 1
# * Скачать данные по ссылке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information
# * Считать данные с помощью pandas
# * Вывести на экран первые 5 строк

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data3.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
# Если реновации дома не было, то в новом признаке поставьте 0

# %%
def fun(arg1):
    if arg1 < 0:
        return 0
    else:
        return arg1

df['delta_renovated'] = df['yr_renovated'] - df['yr_built']
df['delta_renovated'] = df['delta_renovated'].apply(fun)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# 1.3 Создайте признаки года продажи, месяца продажи

# %%
df['year_sale'] = 0
df['month_sale'] = 0
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %% [markdown]
# 1.4 Удалите признаки date, zipcode, lat, long

# %%
df = df.drop(columns='date')
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
df.drop(columns='zipcode', inplace=True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df.drop(columns=['lat', 'long'], inplace=True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# ### Условие 2: 2 задача
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })

# %%
clients = pd.DataFrame({ 
    'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 
                  2295, 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 
                  2134, 2242, 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 
                  1611, 1474], 
    'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 
                 6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 
                 8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150, 
                 809001400, 339600110, 1622049154, 1099600250, 8563000110, 2768100205, 
                 3995700435, 8861700030, 3303980210, 7731100066, 8146100580, 825069097, 
                 3889100029, 9524100196] })

# %%
clients
# Out:
#     client_id    house_id
# 0        1459  8965450190
# 1        4684  6823100225
# 2        3498  5104540330
# 3        3942  2131701075
# 4        4535  1522700060
# 5        2308  1189000207
# 6        2866  6821600300
# 7        2765  7137950720
# 8        1472  9510920050
# 9        4236  6131600255
# 10       2295  5428000070
# 11        939  1788800910
# 12       3840  8100400160
# 13        280  3123049142
# 14         20  6306800010
# 15       4332  5083000375
# 16       3475  7920100025
# 17       4213  1951600150
# 18       3113   809001400
# 19       4809   339600110
# 20       2134  1622049154
# 21       2242  1099600250
# 22       2068  8563000110
# 23       4929  2768100205
# 24       1384  3995700435
# 25       1589  8861700030
# 26       3317  3303980210
# 27       2260  7731100066
# 28       1727  8146100580
# 29       1764   825069097
# 30       1611  3889100029
# 31       1474  9524100196

# %%
clients.head()
# Out:
#    client_id    house_id
# 0       1459  8965450190
# 1       4684  6823100225
# 2       3498  5104540330
# 3       3942  2131701075
# 4       4535  1522700060

# %% [markdown]
# 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
h_id = clients.set_index('house_id')
h_id.head()
# Out:
#             client_id
# house_id
# 8965450190       1459
# 6823100225       4684
# 5104540330       3498
# 2131701075       3942
# 1522700060       4535

# %%
n_id = df.set_index('id')
n_id.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
#             yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# id
# ...

# %%
h_id.join(n_id).reset_index().head()
# Out:
#         index  client_id     price  bedrooms  bathrooms  sqft_living  \
# 0   339600110       4809  395000.0         3       2.50         1610
# 1   809001400       3113  925000.0         3       1.00         1630
# 2   825069097       1764  770000.0         3       2.50         2650
# 3  1099600250       2242  260000.0         3       1.75         1710
# 4  1189000207       2308  387000.0         2       2.50         1170
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      3755     2.0           0     0  ...      7        1610              0
# 1      3200     1.5           0     0  ...      8        1630              0
# 2     40705     2.0           0     0  ...      9        2650              0
# 3      6400     1.0           0     0  ...      7        1240            470
# 4      1394     2.0           0     0  ...      8        1170              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# ...

# %% [markdown]
# 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
# house_id - это индексы датафрейма с домами

# %%
merged = clients.merge(df, left_on='house_id', right_on='id')
merged.head()
# Out:
#    client_id    house_id          id     price  bedrooms  bathrooms  \
# 0       1459  8965450190  8965450190  295000.0         3       2.50
# 1       4684  6823100225  6823100225  700000.0         4       1.75
# 2       3498  5104540330  5104540330  679000.0         4       2.50
# 3       3942  2131701075  2131701075  420000.0         3       1.75
# 4       4535  1522700060  1522700060  518000.0         4       2.75
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1500      3060     2.0           0  ...      7        1500
# 1         1870      6000     1.0           0  ...      8        1670
# 2         3680      7236     2.0           0  ...     10        3680
# 3         1720      5000     1.5           0  ...      8        1720
# 4         2520     14021     2.0           0  ...      9        2520
#
#    sqft_basement  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# 0              0      1994             0           2700        7734
# ...

# %% [markdown]
# ### Условие 3: 3 задача
# Составьте несколько сводных таблиц

# %% [markdown]
# 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
# Отсортируйте от меньшей стоимости к большей

# %%
grouped = df.groupby('bedrooms')
grouped.groups
# Out:
# {0: [875, 3119, 3467, 4868, 6994, 8477, 8484, 9773, 9854, 12653, 14423, 18379, 19452], 1: [154, 264, 350, 465, 648, 860, 903, 1066, 1149, 1378, 1389, 1457, 1629, 1653, 1734, 1956, 1971, 1975, 2008, 2026, 2031, 2156, 2687, 2927, 2930, 2973, 3042, 3108, 3223, 3253, 3285, 3303, 3383, 3489, 3582, 3602, 3661, 3805, 3837, 3874, 3984, 3987, 4089, 4146, 4390, 4410, 4446, 4651, 4832, 4890, 5135, 5168, 5369, 5570, 5582, 5752, 5832, 5887, 6086, 6105, 6120, 6562, 6779, 6812, 7017, 7261, 7375, 7619, 7636, 7725, 7776, 7949, 7992, 8080, 8133, 8165, 8213, 8262, 8445, 8532, 8533, 8600, 8619, 8623, 8732, 8800, 8814, 8955, 9037, 9131, 9191, 9272, 9406, 9457, 9518, 9545, 9563, 9820, 9821, 9888, ...], 2: [2, 11, 18, 23, 31, 53, 82, 88, 89, 107, 117, 122, 138, 140, 147, 166, 179, 183, 208, 215, 218, 219, 226, 230, 233, 241, 242, 244, 247, 255, 263, 267, 271, 281, 289, 308, 318, 324, 325, 333, 347, 353, 380, 395, 402, 411, 420, 424, 438, 442, 470, 478, 487, 495, 498, 501, 505, 508, 515, 521, 524, 525, 531,
# ...

# %%
group_price = grouped.agg({'price': ['mean']}).sort_values(('price', 'mean'), ascending=True)
group_price
# Out:
#                  price
#                   mean
# bedrooms
# 1         3.176429e+05
# 2         4.013727e+05
# 0         4.095038e+05
# 3         4.662321e+05
# 11        5.200000e+05
# 4         6.354195e+05
# 33        6.400000e+05
# 5         7.865998e+05
# 10        8.193333e+05
# 6         8.255206e+05
# 9         8.939998e+05
# 7         9.511847e+05
# 8         1.105077e+06

# %% [markdown]
# 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
grouped_grade = df.groupby('grade')
grouped_grade.groups
# Out:
# {1: [19452], 3: [1149, 3223, 5832], 4: [350, 465, 1066, 3582, 3885, 4868, 5204, 6480, 7973, 8597, 8619, 8623, 9641, 9794, 11500, 11588, 12075, 14001, 14091, 14581, 15040, 15712, 16340, 16530, 17394, 18052, 18166, 18379, 19344], 5: [36, 166, 263, 264, 411, 478, 523, 700, 704, 820, 834, 860, 996, 1099, 1127, 1141, 1168, 1378, 1453, 1774, 1956, 1975, 2042, 2141, 2813, 2832, 2895, 3062, 3108, 3127, 3261, 3304, 3312, 3377, 3402, 3435, 3493, 3638, 3663, 3805, 3806, 3874, 3882, 3936, 3982, 3998, 4109, 4203, 4333, 4383, 4390, 4494, 4542, 4561, 4640, 4651, 4684, 4935, 5226, 5236, 5284, 5317, 5450, 5479, 5570, 5592, 5593, 5621, 5633, 5639, 5730, 5777, 5856, 5887, 5905, 5921, 5963, 5996, 6071, 6089, 6141, 6356, 6416, 6557, 6662, 6719, 6720, 6750, 6803, 6922, 6945, 7004, 7118, 7169, 7261, 7376, 7636, 7849, 7984, 7992, ...], 6: [2, 25, 44, 46, 84, 111, 117, 118, 122, 138, 177, 188, 191, 200, 204, 208, 215, 233, 241, 243, 247, 249, 279, 281, 308, 311, 319, 324, 325, 343, 345, 346, 347, 380, 443, 4
# ...

# %%
grouped_grade.agg({'price': ['min', 'mean', 'max']})
# Out:
#            price
#              min          mean        max
# grade
# 1       142000.0  1.420000e+05   142000.0
# 3        75000.0  2.056667e+05   280000.0
# 4        80000.0  2.143810e+05   435000.0
# 5        78000.0  2.485240e+05   795000.0
# 6        82000.0  3.019196e+05  1200000.0
# 7        90000.0  4.025903e+05  2050000.0
# 8       140000.0  5.428528e+05  3070000.0
# 9       230000.0  7.735132e+05  2700000.0
# 10      316000.0  1.071771e+06  3600000.0
# 11      420000.0  1.496842e+06  7062500.0
# 12      835000.0  2.191222e+06  5350000.0
# 13     1780000.0  3.709615e+06  7700000.0

# %% [markdown]
# 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
grouped_count = df.groupby(['waterfront', 'view']).size()
grouped_count
# Out:
# waterfront  view
# 0           0       19489
#             1         331
#             2         955
#             3         491
#             4         184
# 1           1           1
#             2           8
#             3          19
#             4         135
# dtype: int64

# %%
grouped_count.to_frame(name = 'count').reset_index()
# Out:
#    waterfront  view  count
# 0           0     0  19489
# 1           0     1    331
# 2           0     2    955
# 3           0     3    491
# 4           0     4    184
# 5           1     1      1
# 6           1     2      8
# 7           1     3     19
# 8           1     4    135

# %% [markdown]
# 3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
grouped_result = df.groupby(['floors', 'bedrooms']).size().sort_values(ascending=False)

# %%
grouped_result.to_frame(name = 'count').reset_index()
# Out:
#     floors  bedrooms  count
# 0      1.0         3   5455
# 1      2.0         4   3682
# 2      2.0         3   3118
# 3      1.0         4   2383
# 4      1.0         2   1951
# 5      1.5         3    786
# 6      2.0         5    775
# 7      1.5         4    698
# 8      1.0         5    605
# 9      2.0         2    497
# 10     3.0         3    405
# 11     1.5         5    185
# 12     1.5         2    182
# 13     1.0         1    162
# 14     3.0         2    123
# 15     2.0         6    119
# 16     1.0         6    104
# 17     3.0         4     61
# 18     2.5         4     58
# 19     2.5         3     56
# 20     1.5         6     30
# 21     2.5         5     23
# 22     1.5         1     21
# 23     2.0         7     19
# 24     2.5         6     14
# 25     3.0         5     13
# 26     2.0         1     12
# 27     1.0         7      9
# 28     1.5         7      7
# 29     2.0         0      6
# 30     2.0         8      6
# 31     3.0         6      5
# ...

# %% [markdown]
# 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
temp = {'price': ['median']}
df.groupby(['condition', 'grade']).agg(temp).reset_index()
# Out:
#    condition grade      price
#                        median
# 0          1     1   142000.0
# 1          1     4   150000.0
# 2          1     5   190000.0
# 3          1     6   255000.0
# 4          1     7   403500.0
# 5          1     8   932500.0
# 6          2     3   280000.0
# 7          2     4   145000.0
# 8          2     5   180000.0
# 9          2     6   235000.0
# 10         2     7   305000.0
# 11         2     8   429000.0
# 12         2     9   715000.0
# 13         2    10  1752500.0
# 14         3     3    75000.0
# 15         3     4   205000.0
# 16         3     5   234475.0
# 17         3     6   265000.0
# 18         3     7   357500.0
# 19         3     8   485000.0
# 20         3     9   689000.0
# 21         3    10   890000.0
# 22         3    11  1209500.0
# 23         3    12  1807500.0
# 24         3    13  2888000.0
# 25         4     4   238525.0
# 26         4     5   229975.0
# 27         4     6   295000.0
# 28         4     7   390000.0
# ...
